# %% [markdown]
# # Esercizio 11.2

# %% [markdown]
# Try to extend the model to obtain a reasonable fit of the following polynomial of order 3:
#
# $$
# f(x)=4-3x-2x^2+3x^3
# $$
# for $x \in [-1,1]$.
#
# Find good (& reasonable) choices for:
#
# - the number of layers
# - the number of neurons in each layer
# - the activation function
# - the optimizer
# - the loss function
#
# Check your NN model by seeing how well your fits predict newly generated test data (including on data outside the range you fit. How well do your NN do on points in the range of $x$ where you trained the model? How about points outside the original training data set?
# Summarize what you have learned about the relationship between model complexity (number of parameters), goodness of fit on training data, and the ability to predict well.

# %% [markdown]
# L'obiettivo di questo esercizio invece è utilizzare una rete neurale per fittare una funzione più complicata, ovvero un polinomio di terzo grado. La potenza delle reti neurali consiste nel fatto che questa non necessita di alcun modello (ad esempio un fit con un polinomio), ma si allena utilizzando direttamente i dati forniti.

# %%
# target parameters of f(x) = polinomio
a = 4
b = -3
c = -2
d = 3

# %%
def pol(x):
    return a + b * x + c * x**2 + d * x**3

# %% [markdown]
# Utilizzo un numero totali di dati pari a 100000, divisi al 95% in dati per il training e al 5% per la validazione.

# %%
import numpy as np

Ntot = 100000

# generate training inputs
seed=0
np.random.seed(seed) # fix random seed
x_train = np.random.uniform(-1, 1, int(Ntot*0.95))
x_valid = np.random.uniform(-1, 1, int(Ntot*0.05))
x_valid.sort()
y_target = pol(x_valid) # ideal (target) linear function

sigma = 0.1 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(a + b * x_train + c * x_train**2 + d * x_train**3, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(a + b * x_valid + c * x_valid**2 + d * x_valid**3, sigma)

# %%
# plot validation and target dataset
import matplotlib.pyplot as plt

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

plt.plot(x_valid, y_target, label='target')
plt.scatter(x_valid, y_valid, color='r', label='validation data')
plt.legend()
plt.grid(True)
plt.xlabel("x", fontsize = 14)
plt.ylabel("f(x)", fontsize = 14)
plt.title("Confronto tra dati di validazione e funzione", fontsize = 15, fontweight = "bold")
plt.show()

# %% [markdown]
# Ho scelto una rete neurale con le seguenti caratteristiche:
# - 5 layers con un numero di neuroni decrescente;
# - funzione di attivazione relu (provandone altre ho notato che questa è la migliore);
# - come ottimizzatore ho utilizzato un stocastic gradient discendent;
# - infine per la funzione di loss ho optato per il mean squared error.

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

tf.random.set_seed(seed)

model = tf.keras.Sequential()
#model.add(Dense(1, input_shape=(1,)))
#model.add(Dense(50, input_shape=(1,)))
model.add(Dense(40,input_shape=(1,)))
model.add(Dense(30, activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(5, activation='relu'))
model.add(Dense(1, activation='relu'))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])
# Out:
# 2024-06-16 14:46:04.043937: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-16 14:46:04.048252: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-16 14:46:04.106330: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-16 14:46:04.106376: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-16 14:46:04.107731: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-16 14:46:04.117729: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-16 14:46:04.119729: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-16 14:46:05.628025: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# get a summary of our composed model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 40)                80
#
#  dense_1 (Dense)             (None, 30)                1230
#
#  dense_2 (Dense)             (None, 20)                620
#
#  dense_3 (Dense)             (None, 10)                210
#
#  dense_4 (Dense)             (None, 5)                 55
#
#  dense_5 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 2201 (8.60 KB)
# Trainable params: 2201 (8.60 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(x=x_train, y=y_train, 
          batch_size=250, epochs=100,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/100
# 380/380 [==============================] - 2s 3ms/step - loss: 0.4432 - mse: 0.4432 - val_loss: 0.0260 - val_mse: 0.0260
# Epoch 2/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0179 - mse: 0.0179 - val_loss: 0.0142 - val_mse: 0.0142
# Epoch 3/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0123 - val_mse: 0.0123
# Epoch 4/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 5/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 6/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 7/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 8/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 9/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 10/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 11/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 12/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 13/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 14/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 15/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 16/100
# 380/380 [==============================] - 1s 4ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 17/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 18/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 19/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 20/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 21/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 22/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 23/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 24/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 25/100
# 380/380 [==============================] - 1s 4ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 26/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 27/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 28/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 29/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 30/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 31/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 32/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 33/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 34/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 35/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 36/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 37/100
# 380/380 [==============================] - 1s 4ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 38/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 39/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 40/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 41/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 42/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 43/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 44/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 45/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 46/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 47/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 48/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 49/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 50/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 51/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 52/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 53/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 54/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 55/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 56/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 57/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 58/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 59/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 60/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 61/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 62/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 63/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 64/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 65/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 66/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 67/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 68/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 69/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 70/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 71/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 72/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 73/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 74/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 75/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 76/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 77/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 78/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 79/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 80/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 81/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 82/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 83/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 84/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 85/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 86/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 87/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 88/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 89/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 90/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 91/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 92/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 93/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 94/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 95/100
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 96/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 97/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 98/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 99/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 100/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0101 - val_mse: 0.0101

# %%
# return weights and biases
model.get_weights()
# Out:
# [array([[ 0.14273174,  0.3841295 , -0.00054941,  0.22087654,  0.12042746,
#          -0.19761536,  0.17470619,  0.33257577,  0.41251555,  0.16772658,
#           0.11674704,  0.3939504 , -0.06682837,  0.169208  , -0.01437925,
#           0.26910928, -0.2961204 ,  0.48260757,  0.38967615,  0.11649072,
#          -0.29072055,  0.28341156, -0.4545878 ,  0.28617722, -0.2704294 ,
#           0.16914178, -0.18639128,  0.05895228,  0.01738054,  0.14408936,
#          -0.26450637, -0.15510315, -0.18770158,  0.17485967, -0.33622876,
#           0.02131479,  0.35667247, -0.41207343,  0.36811692,  0.12590842]],
#        dtype=float32),
#  array([ 0.14514668,  0.03339444, -0.13651103, -0.08508556,  0.05925301,
#          0.00389145, -0.09424708, -0.0249972 ,  0.01320107,  0.06987759,
#         -0.08512171,  0.12941556, -0.01170814,  0.12281486,  0.09696043,
#          0.0867976 ,  0.02407669,  0.05372895,  0.04705085,  0.12059052,
#         -0.07801478,  0.06308668, -0.04705213,  0.05726714, -0.12114836,
#          0.03293299, -0.05286799,  0.01333865,  0.03221769, -0.15052605,
#         -0.09856206,  0.0238062 , -0.11217782,  0.11304198,  0.04330859,
#          0.029627  ,  0.16851236,  0.03712297,  0.07162801,  0.0842054 ],
#        dtype=float32),
#  array([[ 0.13050461,  0.01096857,  0.20551768, ...,  0.03529554,
#           0.20643243, -0.24884239],
#         [ 0.20568831, -0.1970098 ,  0.24347535, ..., -0.18262163,
#          -0.20617273,  0.12668203],
#         [-0.2701113 , -0.0791964 ,  0.15946843, ...,  0.22881646,
#           0.23580058, -0.09173047],
#         ...,
#          -0.11588724,  0.2962407 ,  0.04500771, -0.3954105 , -0.17638358],
#         [ 0.1298343 ,  0.354476  , -0.36037782, -0.43782672, -0.07214589,
#          -0.1281569 , -0.14782019, -0.06172913,  0.13463712,  0.07514296],
#         [-0.36841896,  0.0648538 , -0.3868957 , -0.15617776, -0.32422242,
#          -0.24899979, -0.43821216, -0.384112  , -0.24560834, -0.21985415],
#         [-0.2421454 ,  0.13722424, -0.28700823, -0.14180964, -0.09165934,
#           0.1267744 , -0.4360239 , -0.2262643 ,  0.3025429 , -0.01556522],
#         [-0.2770059 , -0.2980168 , -0.37727037, -0.44155812, -0.09610954,
#           0.49058983,  0.5561661 , -0.23346013,  0.04936745,  0.6156433 ],
#         [ 0.10331291,  0.24059573,  0.17596322, -0.13811156,  0.3539535 ,
#           0.40923944,  0.18527158, -0.41890767, -0.18848822, -0.39980993],
#         [ 0.31770217, -0.19851235, -0.00914451,  0.12407999, -0.2967962 ,
#          -0.03063169,  0.01735978, -0.15247875,  0.05103498,  0.21912935],
#         [ 0.01453328, -0.16612859,  0.17287058, -0.32876256, -0.43439344,
#          -0.10243786,  0.09294739, -0.05196631,  0.48457217,  0.23438428],
#         [-0.00476003,  0.39899886, -0.41544756, -0.41337892, -0.13673666,
#           0.40871355,  0.19102216, -0.377311  , -0.2766844 ,  0.20251742],
#         [-0.4260567 , -0.42958328,  0.1987347 ,  0.19614567, -0.2831893 ,
#           0.13187848,  0.44886866, -0.24301621,  0.3491658 ,  0.00859831],
#         [-0.32672554,  0.4298227 ,  0.40619275,  0.12147784,  0.05903709,
#           0.4118798 ,  0.0787272 ,  0.02336526, -0.00524919,  0.39309725],
#         [ 0.12118047,  0.3239678 ,  0.32931644,  0.35541594, -0.05869242,
#          -0.5229486 ,  0.3912085 , -0.40698308, -0.34982276, -0.17607471],
#         [-0.203298  , -0.20612642, -0.28162917, -0.04287422,  0.30713055,
#          -0.09250918,  0.1466915 , -0.15099466, -0.36820638, -0.04627617],
#         [-0.01582086,  0.3283655 ,  0.10181829, -0.21072309, -0.12705266,
#          -0.14281861, -0.11415562, -0.17306828,  0.37259096,  0.10266686],
#         [-0.07629588,  0.25144556,  0.18214446, -0.43893635,  0.13826162,
#          -0.47057888, -0.2770876 ,  0.13693172,  0.44038537, -0.5098297 ]],
#        dtype=float32),
#  array([ 0.        ,  0.14797127, -0.00402803, -0.00144662, -0.00355069,
#          0.34473124,  0.10826989,  0.        , -0.07499532,  0.21895687],
#        dtype=float32),
#  array([[-0.30459648, -0.24872503,  0.18756151,  0.47834128, -0.3400318 ],
#         [-0.12279546, -0.3998794 , -0.5024547 , -0.26834783,  0.59115946],
#         [ 0.44135278,  0.16629285, -0.23181224,  0.02163638,  0.2058319 ],
#         [ 0.35126525, -0.38892776, -0.5121969 , -0.05388867, -0.32961816],
#         [ 0.07225621, -0.19096798,  0.5788525 , -0.33403584, -0.15155879],
#         [ 0.12532026,  0.4046983 ,  0.2884768 ,  0.8265152 , -0.74717325],
#         [-0.29151252, -0.51805073,  0.17729929,  0.5679384 , -0.11789189],
#         [-0.14086616,  0.25701243, -0.09127945,  0.03117126, -0.19873586],
#         [-0.0458957 ,  0.3109954 , -0.39745852, -0.7064251 ,  0.37589002],
#         [-0.3489977 , -0.38134742, -0.2696025 ,  0.70490414,  0.22643454]],
#        dtype=float32),
#  array([ 0.        ,  0.        , -0.05517992,  0.690782  ,  0.10641887],
#        dtype=float32),
#  array([[ 0.31478548],
#         [-0.68941474],
#         [-0.16022825],
#         [ 1.657071  ],
#         [-0.9445495 ]], dtype=float32),
#  array([0.69913614], dtype=float32)]

# %%
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0101 - mse: 0.0101
#
# Test loss: 0.010130359791219234
# Test accuracy: 0.010130359791219234

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss', fontsize = 15, fontweight = "bold")
plt.ylabel('Loss')
plt.xlabel('Epoca')
plt.legend(['Train', 'Test'], loc='best')
plt.grid()

# Secondo grafico con ylim diverso
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss (zoom sull\'asse verticale)', fontsize = 15, fontweight = "bold")
plt.ylabel('Loss')
plt.xlabel('Epoca')
plt.legend(['Train', 'Test'], loc='best')
plt.ylim(0.009, 0.012)
plt.grid()

plt.show()

# %%
x_predicted = np.linspace(-1, 1, 1000)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r', marker='.')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.xlabel("x", fontsize = 14)
plt.ylabel("f(x)", fontsize = 14)
plt.title("Confronto tra modello e curva esatta", fontsize = 15, fontweight = "bold")
plt.legend(['Punti del modello', 'Curva esatta'], loc='best')
plt.show()
# Out:
# 32/32 [==============================] - 0s 1ms/step

# %%
x_predicted = np.linspace(-1.5, 1.5, 1000)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r', marker='.')
plt.plot(x_predicted, pol(x_predicted))
plt.title("Confronto tra modello e curva esatta per estrapolazioni", fontsize = 15, fontweight = "bold")
plt.legend(['Punti del modello', 'Curva esatta'], loc='best')
plt.xlabel("x", fontsize = 14)
plt.ylabel("f(x)", fontsize = 14)
plt.grid(True)
plt.show()
# Out:
# 32/32 [==============================] - 0s 1ms/step

# %% [markdown]
# Variando ampiamente i parametri, ho notato che è abbastanza facile ottenere una rete neurale che approssimi la funzione (soprattutto nella parte centrale); tuttavia, ho faticato a trovare un modo per approssimare al meglio la funzione ai bordi.
#
# Quello che ho potuto osservare è che la componente stocastica del metodo SGD è fondamentale: impostando il parametro batch_size a un valore alto (anche con molte epoche), si nota come la rete neurale trovi subito dei parametri soddisfacenti per il fit, ma poi questi, con l'aumentare delle epoche, non migliorano più; al contrario, con batch_size basso, la convergenza è più lenta ma continua a migliorare i parametri. Proprio così sono riuscito a migliorare l'errore commesso dalla rete proprio ai bordi dell'intervallo [-1,1].
#
# Sperimentando, ho notato che aumentando la complessità della rete non è detto che, a parità di dati utilizzati, il risultato migliori; anzi ad un certo punto la complessità del modello diveta troppo elevata rispetto al numeri di dati disponibili per il training. Questo si traduce in un errore che aumenta all'aumentare del numero dei parametri della rete.
#
# Per quanto riguarda il potere predittivo della rete neurale, questo risulta piuttosto buono nell'intervallo in cui è stata allenata; tuttavia, se proviamo ad estendere il modello oltre, ci accorgiamo che ne non ha alcuno.
